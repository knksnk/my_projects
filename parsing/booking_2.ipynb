# %% [markdown]
# # Booking (бронирование отелей)
# **Цели:** <br>● провести предобработку данных, для последующего их удобного анализа
# <br>
# ● проанализировать данные в соответсвии с имеющимися задачами
# <br>
# <br>
# **Задачи:** <br>● Выяснитьи из каких стран пользовател совершили наибольшее число успешных бронирований?
# <br>
# ● Посчитать количество случаев, когда тип номера, полученного клиентом (assigned_room_type), отличается от изначально забронированного (reserved_room_type)
# <br>
# ● Узнать на какой месяц чаще всего оформляли бронь в 2016 году и изменился ли он в 2017 году?
# <br>
# ● Понять на какой месяц (arrival_date_month) бронирования отеля типа City Hotel отменялись чаще всего в 2015? 2016? 2017?
# <br>
# ● Посчитать сколько клиентов было потеряно по двум группам: клиенты с детьми, клиенты без детей. Иными словами, посчитать метрику под названием Churn Rate.
# <br>
# <br>
# **Входные данные:** <br>входные данные представляют собой файл csv, содержащий в себе информацию о бронировании отелей
# <br>
# <br>
# **Используемые библиотеки:** <br>pandas
# <br>numpy
# <br>
# <br>
# Для начала импортируем библиотеки

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Считаем файл с данными, который мы предварительно сохранили. Заметим, что вместо запятых, характерных для файлов "csv", там используются ";". Учтем это при считывании. Запишем его в переменную df:

# %%
df = pd.read_csv("booking.csv", sep = ";")

# %% [markdown]
# Выведем основную информацию о данных:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Hotel                     119390 non-null  object
#  1   Is Canceled               119390 non-null  int64
#  2   Lead Time                 119390 non-null  int64
#  3   arrival full date         119390 non-null  object
#  4   Arrival Date Week Number  119390 non-null  int64
#  5   Stays in Weekend nights   119390 non-null  int64
#  6   Stays in week nights      119390 non-null  int64
#  7   stays total nights        119390 non-null  int64
#  8   Adults                    119390 non-null  int64
#  9   Children                  119386 non-null  float64
#  10  Babies                    119390 non-null  int64
#  11  Meal                      119390 non-null  object
#  12  Country                   118902 non-null  object
#  13  Reserved Room Type        119390 non-null  object
#  14  Assigned room type        119390 non-null  object
#  15  customer type             119390 non-null  object
#  16  Reservation Status        119390 non-null  object
#  17  Reservation status_date   119390 non-null  object
# dtypes: float64(1), int64(8), object(9)
# memory usage: 16.4+ MB

# %% [markdown]
# Описание данных:
# <br>● Hotel – тип отеля (City Hotel или Resort Hotel)
# <br>● Is canceled – бронирование было отменено (1) или нет (0); неотменённое считается успешным
# <br>● Lead time – количество дней, прошедших между датой бронирования и датой прибытия
# <br>● Arrival full date – полная дата прибытия
# <br>● Arrival date week number – номер недели прибытия
# <br>● Stays in weekend nights – количество выходных (суббота или воскресенье), которые гость забронировал для проживания в отеле
# <br>● Stays in week nights – количество дней (с понедельника по пятницу), которые гость забронировал для проживания в отеле
# <br>● Stays total nights – общее число забронированных ночей (сумма двух предыдущих колонок)
# <br>● Adults – число взрослых
# <br>● Children – число детей
# <br>●Babies – число младенцев
# <br>● Meal – выбранный тип питания
# <br>● Country – страна происхождения клиента
# <br>● Reserved room type – тип зарезервированного номера
# <br>● Assigned room type – тип полученного номера (может отличаться от забронированного)
# <br>● Customer type – тип бронирования
# <br>● Reservation status – значение последнего статуса брони: Canceled – было отменено клиентом; Check-Out – клиент зарегистрировался, но уже покинул отель; No-Show – клиент не зарегистрировался и сообщил администрации отеля причину
# <br>● Reservation status date – дата обновления статуса
#
# Всего 119390 строк и 18 столбцов, при этом в некоторых столбцах существуют пропуски. Обратим внимание на типы данных, но вернемся к этому вопросу после удаления всего лишнего.

# %%
df.head()
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  \
# 0  Resort Hotel            0        342        01.07.2015
# 1  Resort Hotel            0        737        01.07.2015
# 2  Resort Hotel            0          7        01.07.2015
# 3  Resort Hotel            0         13        01.07.2015
# 4  Resort Hotel            0         14        01.07.2015
#
#    Arrival Date Week Number  Stays in Weekend nights  Stays in week nights  \
# 0                        27                        0                     0
# 1                        27                        0                     0
# 2                        27                        0                     1
# 3                        27                        0                     1
# 4                        27                        0                     2
#
#    stays total nights  Adults  Children  Babies Meal Country  \
# 0                   0       2       0.0       0   BB     PRT
# 1                   0       2       0.0       0   BB     PRT
# 2                   1       1       0.0       0   BB     GBR
# 3                   1       1       0.0       0   BB     GBR
# 4                   2       2       0.0       0   BB     GBR
#
#   Reserved Room Type Assigned room type customer type Reservation Status  \
# 0                  C                  C     Transient          Check-Out
# 1                  C                  C     Transient          Check-Out
# 2                  A                  C     Transient          Check-Out
# 3                  A                  A     Transient          Check-Out
# 4                  A                  A     Transient          Check-Out
#
#   Reservation status_date
# 0              01.07.2015
# 1              01.07.2015
# 2              02.07.2015
# 3              02.07.2015
# 4              03.07.2015

# %% [markdown]
# Названия столбцов написаны не в стиле snake_case. Исправим это:

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ", "_")
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_week_number', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 36235

# %%
df = df.drop_duplicates()

# %% [markdown]
# Теперь поймем, что для наших задач некоторые столбцы не нужны. Удалим их:

# %%
 df = df.drop(['lead_time',
       'arrival_date_week_number', 'stays_in_weekend_nights',
       'stays_in_week_nights', 'stays_total_nights', 'adults', "meal",
       'customer_type', "reservation_status", "reservation_status_date"], axis=1)
df.head()
# Out:
#           hotel  is_canceled arrival_full_date  children  babies country  \
# 0  Resort Hotel            0        01.07.2015       0.0       0     PRT
# 1  Resort Hotel            0        01.07.2015       0.0       0     PRT
# 2  Resort Hotel            0        01.07.2015       0.0       0     GBR
# 3  Resort Hotel            0        01.07.2015       0.0       0     GBR
# 4  Resort Hotel            0        01.07.2015       0.0       0     GBR
#
#   reserved_room_type assigned_room_type
# 0                  C                  C
# 1                  C                  C
# 2                  A                  C
# 3                  A                  A
# 4                  A                  A

# %% [markdown]
# Проверим на количество пропусков:

# %%
df.isna().mean()
# Out:
# hotel                 0.000000
# is_canceled           0.000000
# arrival_full_date     0.000000
# children              0.000048
# babies                0.000000
# country               0.005207
# reserved_room_type    0.000000
# assigned_room_type    0.000000
# dtype: float64

# %% [markdown]
# Проценты пропусков среди тех столбцов, где они есть, везде маленькие, заменим их на другие значения, чтобы не было ошибки во время анализа

# %%
df["children"] = df["children"].fillna(0)
df["country"] = df["country"].fillna("No")
df.isna().mean()
# Out:
# hotel                 0.0
# is_canceled           0.0
# arrival_full_date     0.0
# children              0.0
# babies                0.0
# country               0.0
# reserved_room_type    0.0
# assigned_room_type    0.0
# dtype: float64

# %% [markdown]
# Теперь пропусков нет.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83155 entries, 0 to 119389
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   hotel               83155 non-null  object
#  1   is_canceled         83155 non-null  int64
#  2   arrival_full_date   83155 non-null  object
#  3   children            83155 non-null  float64
#  4   babies              83155 non-null  int64
#  5   country             83155 non-null  object
#  6   reserved_room_type  83155 non-null  object
#  7   assigned_room_type  83155 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 5.7+ MB

# %% [markdown]
# Нужно изменить типы данных в некоторых столбцах. Так например столбец "children" имеет тип float

# %%
df["children"] = df["children"].astype(int)

# %% [markdown]
# Еще для удобства я переименую значения в первом столбце. "Resort Hotel" заменю на "R", а "City Hotel" на "С"

# %%
df["hotel"] = df["hotel"].apply(lambda x: x[0])
df.head()
# Out:
#   hotel  is_canceled arrival_full_date  children  babies country  \
# 0     R            0        01.07.2015         0       0     PRT
# 1     R            0        01.07.2015         0       0     PRT
# 2     R            0        01.07.2015         0       0     GBR
# 3     R            0        01.07.2015         0       0     GBR
# 4     R            0        01.07.2015         0       0     GBR
#
#   reserved_room_type assigned_room_type
# 0                  C                  C
# 1                  C                  C
# 2                  A                  C
# 3                  A                  A
# 4                  A                  A

# %% [markdown]
# Проверим уникальные значений по каждому столбцу, чтобы убедиться, что все данные имеют одинаковый вид.

# %%
df['hotel'].sort_values().unique()
# Out:
# array(['C', 'R'], dtype=object)

# %%
df['is_canceled'].sort_values().unique()
# Out:
# array([0, 1])

# %%
df['arrival_full_date'].sort_values().unique()
# Out:
# array(['01.01.2016', '01.01.2017', '01.02.2016', '01.02.2017',
#        '01.03.2016', '01.03.2017', '01.04.2016', '01.04.2017',
#        '01.05.2016', '01.05.2017', '01.06.2016', '01.06.2017',
#        '01.07.2015', '01.07.2016', '01.07.2017', '01.08.2015',
#        '01.08.2016', '01.08.2017', '01.09.2015', '01.09.2016',
#        '01.10.2015', '01.10.2016', '01.11.2015', '01.11.2016',
#        '01.12.2015', '01.12.2016', '02.01.2016', '02.01.2017',
#        '02.02.2016', '02.02.2017', '02.03.2016', '02.03.2017',
#        '02.04.2016', '02.04.2017', '02.05.2016', '02.05.2017',
#        '02.06.2016', '02.06.2017', '02.07.2015', '02.07.2016',
#        '02.07.2017', '02.08.2015', '02.08.2016', '02.08.2017',
#        '02.09.2015', '02.09.2016', '02.10.2015', '02.10.2016',
#        '02.11.2015', '02.11.2016', '02.12.2015', '02.12.2016',
#        '03.01.2016', '03.01.2017', '03.02.2016', '03.02.2017',
#        '03.03.2016', '03.03.2017', '03.04.2016', '03.04.2017',
#        '03.05.2016', '03.05.2017', '03.06.2016', '03.06.2017',
#        '03.07.2015', '03.07.2016', '03.07.2017', '03.08.2015',
#        '03.08.2016', '03.08.2017', '03.09.2015', '03.09.2016',
#        '03.10.2015', '03.10.2016', '03.11.2015', '03.11.2016',
#        '03.12.2015', '03.12.2016', '04.01.2016', '04.01.2017',
#        '04.02.2016', '04.02.2017', '04.03.2016', '04.03.2017',
#        '04.04.2016', '04.04.2017', '04.05.2016', '04.05.2017',
#        '04.06.2016', '04.06.2017', '04.07.2015', '04.07.2016',
#        '04.07.2017', '04.08.2015', '04.08.2016', '04.08.2017',
#        '04.09.2015', '04.09.2016', '04.10.2015', '04.10.2016',
#        '04.11.2015', '04.11.2016', '04.12.2015', '04.12.2016',
#        '05.01.2016', '05.01.2017', '05.02.2016', '05.02.2017',
#        '05.03.2016', '05.03.2017', '05.04.2016', '05.04.2017',
#        '05.05.2016', '05.05.2017', '05.06.2016', '05.06.2017',
#        '05.07.2015', '05.07.2016', '05.07.2017', '05.08.2015',
#        '05.08.2016', '05.08.2017', '05.09.2015', '05.09.2016',
#        '05.10.2015', '05.10.2016', '05.11.2015', '05.11.2016',
#        '05.12.2015', '05.12.2016', '06.01.2016', '06.01.2017',
#        '06.02.2016', '06.02.2017', '06.03.2016', '06.03.2017',
#        '06.04.2016', '06.04.2017', '06.05.2016', '06.05.2017',
#        '06.06.2016', '06.06.2017', '06.07.2015', '06.07.2016',
#        '06.07.2017', '06.08.2015', '06.08.2016', '06.08.2017',
#        '06.09.2015', '06.09.2016', '06.10.2015', '06.10.2016',
#        '06.11.2015', '06.11.2016', '06.12.2015', '06.12.2016',
#        '07.01.2016', '07.01.2017', '07.02.2016', '07.02.2017',
#        '07.03.2016', '07.03.2017', '07.04.2016', '07.04.2017',
#        '07.05.2016', '07.05.2017', '07.06.2016', '07.06.2017',
#        '07.07.2015', '07.07.2016', '07.07.2017', '07.08.2015',
#        '07.08.2016', '07.08.2017', '07.09.2015', '07.09.2016',
#        '07.10.2015', '07.10.2016', '07.11.2015', '07.11.2016',
#        '07.12.2015', '07.12.2016', '08.01.2016', '08.01.2017',
#        '08.02.2016', '08.02.2017', '08.03.2016', '08.03.2017',
#        '08.04.2016', '08.04.2017', '08.05.2016', '08.05.2017',
#        '08.06.2016', '08.06.2017', '08.07.2015', '08.07.2016',
#        '08.07.2017', '08.08.2015', '08.08.2016', '08.08.2017',
#        '08.09.2015', '08.09.2016', '08.10.2015', '08.10.2016',
#        '08.11.2015', '08.11.2016', '08.12.2015', '08.12.2016',
#        '09.01.2016', '09.01.2017', '09.02.2016', '09.02.2017',
#        '09.03.2016', '09.03.2017', '09.04.2016', '09.04.2017',
#        '09.05.2016', '09.05.2017', '09.06.2016', '09.06.2017',
#        '09.07.2015', '09.07.2016', '09.07.2017', '09.08.2015',
#        '09.08.2016', '09.08.2017', '09.09.2015', '09.09.2016',
#        '09.10.2015', '09.10.2016', '09.11.2015', '09.11.2016',
#        '09.12.2015', '09.12.2016', '10.01.2016', '10.01.2017',
#        '10.02.2016', '10.02.2017', '10.03.2016', '10.03.2017',
#        '10.04.2016', '10.04.2017', '10.05.2016', '10.05.2017',
#        '10.06.2016', '10.06.2017', '10.07.2015', '10.07.2016',
#        '10.07.2017', '10.08.2015', '10.08.2016', '10.08.2017',
#        '10.09.2015', '10.09.2016', '10.10.2015', '10.10.2016',
#        '10.11.2015', '10.11.2016', '10.12.2015', '10.12.2016',
#        '11.01.2016', '11.01.2017', '11.02.2016', '11.02.2017',
#        '11.03.2016', '11.03.2017', '11.04.2016', '11.04.2017',
#        '11.05.2016', '11.05.2017', '11.06.2016', '11.06.2017',
#        '11.07.2015', '11.07.2016', '11.07.2017', '11.08.2015',
#        '11.08.2016', '11.08.2017', '11.09.2015', '11.09.2016',
#        '11.10.2015', '11.10.2016', '11.11.2015', '11.11.2016',
#        '11.12.2015', '11.12.2016', '12.01.2016', '12.01.2017',
#        '12.02.2016', '12.02.2017', '12.03.2016', '12.03.2017',
#        '12.04.2016', '12.04.2017', '12.05.2016', '12.05.2017',
#        '12.06.2016', '12.06.2017', '12.07.2015', '12.07.2016',
#        '12.07.2017', '12.08.2015', '12.08.2016', '12.08.2017',
#        '12.09.2015', '12.09.2016', '12.10.2015', '12.10.2016',
#        '12.11.2015', '12.11.2016', '12.12.2015', '12.12.2016',
#        '13.01.2016', '13.01.2017', '13.02.2016', '13.02.2017',
#        '13.03.2016', '13.03.2017', '13.04.2016', '13.04.2017',
#        '13.05.2016', '13.05.2017', '13.06.2016', '13.06.2017',
#        '13.07.2015', '13.07.2016', '13.07.2017', '13.08.2015',
#        '13.08.2016', '13.08.2017', '13.09.2015', '13.09.2016',
#        '13.10.2015', '13.10.2016', '13.11.2015', '13.11.2016',
#        '13.12.2015', '13.12.2016', '14.01.2016', '14.01.2017',
#        '14.02.2016', '14.02.2017', '14.03.2016', '14.03.2017',
#        '14.04.2016', '14.04.2017', '14.05.2016', '14.05.2017',
#        '14.06.2016', '14.06.2017', '14.07.2015', '14.07.2016',
#        '14.07.2017', '14.08.2015', '14.08.2016', '14.08.2017',
#        '14.09.2015', '14.09.2016', '14.10.2015', '14.10.2016',
#        '14.11.2015', '14.11.2016', '14.12.2015', '14.12.2016',
#        '15.01.2016', '15.01.2017', '15.02.2016', '15.02.2017',
#        '15.03.2016', '15.03.2017', '15.04.2016', '15.04.2017',
#        '15.05.2016', '15.05.2017', '15.06.2016', '15.06.2017',
#        '15.07.2015', '15.07.2016', '15.07.2017', '15.08.2015',
#        '15.08.2016', '15.08.2017', '15.09.2015', '15.09.2016',
#        '15.10.2015', '15.10.2016', '15.11.2015', '15.11.2016',
#        '15.12.2015', '15.12.2016', '16.01.2016', '16.01.2017',
#        '16.02.2016', '16.02.2017', '16.03.2016', '16.03.2017',
#        '16.04.2016', '16.04.2017', '16.05.2016', '16.05.2017',
#        '16.06.2016', '16.06.2017', '16.07.2015', '16.07.2016',
#        '16.07.2017', '16.08.2015', '16.08.2016', '16.08.2017',
#        '16.09.2015', '16.09.2016', '16.10.2015', '16.10.2016',
#        '16.11.2015', '16.11.2016', '16.12.2015', '16.12.2016',
#        '17.01.2016', '17.01.2017', '17.02.2016', '17.02.2017',
#        '17.03.2016', '17.03.2017', '17.04.2016', '17.04.2017',
#        '17.05.2016', '17.05.2017', '17.06.2016', '17.06.2017',
#        '17.07.2015', '17.07.2016', '17.07.2017', '17.08.2015',
#        '17.08.2016', '17.08.2017', '17.09.2015', '17.09.2016',
#        '17.10.2015', '17.10.2016', '17.11.2015', '17.11.2016',
#        '17.12.2015', '17.12.2016', '18.01.2016', '18.01.2017',
#        '18.02.2016', '18.02.2017', '18.03.2016', '18.03.2017',
#        '18.04.2016', '18.04.2017', '18.05.2016', '18.05.2017',
#        '18.06.2016', '18.06.2017', '18.07.2015', '18.07.2016',
#        '18.07.2017', '18.08.2015', '18.08.2016', '18.08.2017',
#        '18.09.2015', '18.09.2016', '18.10.2015', '18.10.2016',
#        '18.11.2015', '18.11.2016', '18.12.2015', '18.12.2016',
#        '19.01.2016', '19.01.2017', '19.02.2016', '19.02.2017',
#        '19.03.2016', '19.03.2017', '19.04.2016', '19.04.2017',
#        '19.05.2016', '19.05.2017', '19.06.2016', '19.06.2017',
#        '19.07.2015', '19.07.2016', '19.07.2017', '19.08.2015',
#        '19.08.2016', '19.08.2017', '19.09.2015', '19.09.2016',
#        '19.10.2015', '19.10.2016', '19.11.2015', '19.11.2016',
#        '19.12.2015', '19.12.2016', '20.01.2016', '20.01.2017',
#        '20.02.2016', '20.02.2017', '20.03.2016', '20.03.2017',
#        '20.04.2016', '20.04.2017', '20.05.2016', '20.05.2017',
#        '20.06.2016', '20.06.2017', '20.07.2015', '20.07.2016',
#        '20.07.2017', '20.08.2015', '20.08.2016', '20.08.2017',
#        '20.09.2015', '20.09.2016', '20.10.2015', '20.10.2016',
#        '20.11.2015', '20.11.2016', '20.12.2015', '20.12.2016',
#        '21.01.2016', '21.01.2017', '21.02.2016', '21.02.2017',
#        '21.03.2016', '21.03.2017', '21.04.2016', '21.04.2017',
#        '21.05.2016', '21.05.2017', '21.06.2016', '21.06.2017',
#        '21.07.2015', '21.07.2016', '21.07.2017', '21.08.2015',
#        '21.08.2016', '21.08.2017', '21.09.2015', '21.09.2016',
#        '21.10.2015', '21.10.2016', '21.11.2015', '21.11.2016',
#        '21.12.2015', '21.12.2016', '22.01.2016', '22.01.2017',
#        '22.02.2016', '22.02.2017', '22.03.2016', '22.03.2017',
#        '22.04.2016', '22.04.2017', '22.05.2016', '22.05.2017',
#        '22.06.2016', '22.06.2017', '22.07.2015', '22.07.2016',
#        '22.07.2017', '22.08.2015', '22.08.2016', '22.08.2017',
#        '22.09.2015', '22.09.2016', '22.10.2015', '22.10.2016',
#        '22.11.2015', '22.11.2016', '22.12.2015', '22.12.2016',
#        '23.01.2016', '23.01.2017', '23.02.2016', '23.02.2017',
#        '23.03.2016', '23.03.2017', '23.04.2016', '23.04.2017',
#        '23.05.2016', '23.05.2017', '23.06.2016', '23.06.2017',
#        '23.07.2015', '23.07.2016', '23.07.2017', '23.08.2015',
#        '23.08.2016', '23.08.2017', '23.09.2015', '23.09.2016',
#        '23.10.2015', '23.10.2016', '23.11.2015', '23.11.2016',
#        '23.12.2015', '23.12.2016', '24.01.2016', '24.01.2017',
#        '24.02.2016', '24.02.2017', '24.03.2016', '24.03.2017',
#        '24.04.2016', '24.04.2017', '24.05.2016', '24.05.2017',
#        '24.06.2016', '24.06.2017', '24.07.2015', '24.07.2016',
#        '24.07.2017', '24.08.2015', '24.08.2016', '24.08.2017',
#        '24.09.2015', '24.09.2016', '24.10.2015', '24.10.2016',
#        '24.11.2015', '24.11.2016', '24.12.2015', '24.12.2016',
#        '25.01.2016', '25.01.2017', '25.02.2016', '25.02.2017',
#        '25.03.2016', '25.03.2017', '25.04.2016', '25.04.2017',
#        '25.05.2016', '25.05.2017', '25.06.2016', '25.06.2017',
#        '25.07.2015', '25.07.2016', '25.07.2017', '25.08.2015',
#        '25.08.2016', '25.08.2017', '25.09.2015', '25.09.2016',
#        '25.10.2015', '25.10.2016', '25.11.2015', '25.11.2016',
#        '25.12.2015', '25.12.2016', '26.01.2016', '26.01.2017',
#        '26.02.2016', '26.02.2017', '26.03.2016', '26.03.2017',
#        '26.04.2016', '26.04.2017', '26.05.2016', '26.05.2017',
#        '26.06.2016', '26.06.2017', '26.07.2015', '26.07.2016',
#        '26.07.2017', '26.08.2015', '26.08.2016', '26.08.2017',
#        '26.09.2015', '26.09.2016', '26.10.2015', '26.10.2016',
#        '26.11.2015', '26.11.2016', '26.12.2015', '26.12.2016',
#        '27.01.2016', '27.01.2017', '27.02.2016', '27.02.2017',
#        '27.03.2016', '27.03.2017', '27.04.2016', '27.04.2017',
#        '27.05.2016', '27.05.2017', '27.06.2016', '27.06.2017',
#        '27.07.2015', '27.07.2016', '27.07.2017', '27.08.2015',
#        '27.08.2016', '27.08.2017', '27.09.2015', '27.09.2016',
#        '27.10.2015', '27.10.2016', '27.11.2015', '27.11.2016',
#        '27.12.2015', '27.12.2016', '28.01.2016', '28.01.2017',
#        '28.02.2016', '28.02.2017', '28.03.2016', '28.03.2017',
#        '28.04.2016', '28.04.2017', '28.05.2016', '28.05.2017',
#        '28.06.2016', '28.06.2017', '28.07.2015', '28.07.2016',
#        '28.07.2017', '28.08.2015', '28.08.2016', '28.08.2017',
#        '28.09.2015', '28.09.2016', '28.10.2015', '28.10.2016',
#        '28.11.2015', '28.11.2016', '28.12.2015', '28.12.2016',
#        '29.01.2016', '29.01.2017', '29.02.2016', '29.03.2016',
#        '29.03.2017', '29.04.2016', '29.04.2017', '29.05.2016',
#        '29.05.2017', '29.06.2016', '29.06.2017', '29.07.2015',
#        '29.07.2016', '29.07.2017', '29.08.2015', '29.08.2016',
#        '29.08.2017', '29.09.2015', '29.09.2016', '29.10.2015',
#        '29.10.2016', '29.11.2015', '29.11.2016', '29.12.2015',
#        '29.12.2016', '30.01.2016', '30.01.2017', '30.03.2016',
#        '30.03.2017', '30.04.2016', '30.04.2017', '30.05.2016',
#        '30.05.2017', '30.06.2016', '30.06.2017', '30.07.2015',
#        '30.07.2016', '30.07.2017', '30.08.2015', '30.08.2016',
#        '30.08.2017', '30.09.2015', '30.09.2016', '30.10.2015',
#        '30.10.2016', '30.11.2015', '30.11.2016', '30.12.2015',
#        '30.12.2016', '31.01.2016', '31.01.2017', '31.03.2016',
#        '31.03.2017', '31.05.2016', '31.05.2017', '31.07.2015',
#        '31.07.2016', '31.07.2017', '31.08.2015', '31.08.2016',
#        '31.08.2017', '31.10.2015', '31.10.2016', '31.12.2015',
#        '31.12.2016'], dtype=object)

# %%
df['children'].sort_values().unique()
# Out:
# array([ 0,  1,  2,  3, 10])

# %%
df['babies'].sort_values().unique()
# Out:
# array([ 0,  1,  2,  9, 10])

# %%
df['country'].sort_values().unique()
# Out:
# array(['ABW', 'AGO', 'AIA', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM',
#        'ATA', 'ATF', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA',
#        'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BOL', 'BRA', 'BRB',
#        'BWA', 'CAF', 'CHE', 'CHL', 'CHN', 'CIV', 'CMR', 'CN', 'COL',
#        'COM', 'CPV', 'CRI', 'CUB', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI',
#        'DMA', 'DNK', 'DOM', 'DZA', 'ECU', 'EGY', 'ESP', 'EST', 'ETH',
#        'FIN', 'FJI', 'FRA', 'FRO', 'GAB', 'GBR', 'GEO', 'GGY', 'GHA',
#        'GIB', 'GLP', 'GNB', 'GRC', 'GTM', 'GUY', 'HKG', 'HND', 'HRV',
#        'HUN', 'IDN', 'IMN', 'IND', 'IRL', 'IRN', 'IRQ', 'ISL', 'ISR',
#        'ITA', 'JAM', 'JEY', 'JOR', 'JPN', 'KAZ', 'KEN', 'KHM', 'KIR',
#        'KNA', 'KOR', 'KWT', 'LAO', 'LBN', 'LBY', 'LCA', 'LIE', 'LKA',
#        'LTU', 'LUX', 'LVA', 'MAC', 'MAR', 'MCO', 'MDG', 'MDV', 'MEX',
#        'MKD', 'MLI', 'MLT', 'MMR', 'MNE', 'MOZ', 'MRT', 'MUS', 'MWI',
#        'MYS', 'MYT', 'NAM', 'NCL', 'NGA', 'NIC', 'NLD', 'NOR', 'NPL',
#        'NZL', 'No', 'OMN', 'PAK', 'PAN', 'PER', 'PHL', 'PLW', 'POL',
#        'PRI', 'PRT', 'PRY', 'PYF', 'QAT', 'ROU', 'RUS', 'RWA', 'SAU',
#        'SDN', 'SEN', 'SGP', 'SLE', 'SLV', 'SMR', 'SRB', 'STP', 'SUR',
#        'SVK', 'SVN', 'SWE', 'SYC', 'SYR', 'TGO', 'THA', 'TJK', 'TMP',
#        'TUN', 'TUR', 'TWN', 'TZA', 'UGA', 'UKR', 'UMI', 'URY', 'USA',
#        'UZB', 'VEN', 'VGB', 'VNM', 'ZAF', 'ZMB', 'ZWE'], dtype=object)

# %%
df['reserved_room_type'].sort_values().unique()
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'L', 'P'], dtype=object)

# %%
df['assigned_room_type'].sort_values().unique()
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'P'],
#       dtype=object)

# %% [markdown]
# Все данные в каждом столбце имеют одинаковый вид. Перейдем к выполнению задач.
# <br>
# <br>
# ## Выяснитьи из каких стран пользовател совершили наибольшее число успешных бронирований?

# %% [markdown]
# Заменим значения с столбце "is_canceled" для удобства дальнейшей работы. Теперь 0 будет заменен на -1, т.е. если отмены брони не было, тогда это будет обозначено "-1"

# %%
df.loc[:, 'is_canceled'] = df.loc[:, 'is_canceled'].replace(0, -1)

# %% [markdown]
# Создадим df1, к котрому применим фильтр, обозначающий, что бронь отменена не была.

# %%
df1 = df.query('is_canceled == -1')
df1.head()
# Out:
#   hotel  is_canceled arrival_full_date  children  babies country  \
# 0     R           -1        01.07.2015         0       0     PRT
# 1     R           -1        01.07.2015         0       0     PRT
# 2     R           -1        01.07.2015         0       0     GBR
# 3     R           -1        01.07.2015         0       0     GBR
# 4     R           -1        01.07.2015         0       0     GBR
#
#   reserved_room_type assigned_room_type
# 0                  C                  C
# 1                  C                  C
# 2                  A                  C
# 3                  A                  A
# 4                  A                  A

# %% [markdown]
# Теперь создадим сводную таблицу, в которой посчитаем сумму значений столбца "is_canceled" для каждой страны

# %%
df2 = pd.pivot_table(df1,
               values=["is_canceled"],
               index =["country"],
               aggfunc=[np.sum])

# %% [markdown]
# Отсортируем таблицу по значениям столбца "('sum', "is_canceled")"

# %%
df2 = df2.sort_values([('sum', "is_canceled")])

# %% [markdown]
# Таким образом наибольшие по модулю значение в столбце "('sum', "is_canceled")" будут обозночать страну, где было совершено наибольшее количество успешных бронирований. Создадим топ 10:

# %%
df2.head(10)
# Out:
#                 sum
#         is_canceled
# country
# PRT          -16138
# GBR           -7803
# FRA           -6808
# ESP           -5076
# DEU           -4130
# IRL           -2215
# ITA           -1887
# BEL           -1616
# NLD           -1512
# USA           -1370

# %% [markdown]
# Получается:
# <br>● Португалия - 16138
# <br>● Великобритания - 7803
# <br>● Франция - 6808
# <br>● Испания - 5076
# <br>● Германия - 4130
# <br>● Ирландия - 2215
# <br>● Италия - 1887
# <br>● Бельгия - 1616
# <br>● Нидерладны - 1512
# <br>● США - 1370

# %% [markdown]
# ## Посчитать количество случаев, когда тип номера, полученного клиентом (assigned_room_type), отличается от изначально забронированного (reserved_room_type)

# %% [markdown]
# Создадим столбец "matching", в который запишем значение **True**, если ячейка столбца "reserved_room_type" равна ячейки столбца "assigned_room_type", иначе **False **

# %%
df["matching"] = df.apply(lambda x: x["reserved_room_type"] == x["assigned_room_type"], axis=1)
df.head(10)
# Out:
#    hotel  is_canceled arrival_full_date  children  babies country  \
# 0      R           -1        01.07.2015         0       0     PRT
# 1      R           -1        01.07.2015         0       0     PRT
# 2      R           -1        01.07.2015         0       0     GBR
# 3      R           -1        01.07.2015         0       0     GBR
# 4      R           -1        01.07.2015         0       0     GBR
# 6      R           -1        01.07.2015         0       0     PRT
# 7      R           -1        01.07.2015         0       0     PRT
# 8      R            1        01.07.2015         0       0     PRT
# 9      R            1        01.07.2015         0       0     PRT
# 10     R            1        01.07.2015         0       0     PRT
#
#    reserved_room_type assigned_room_type  matching
# 0                   C                  C      True
# 1                   C                  C      True
# 2                   A                  C     False
# 3                   A                  A      True
# 4                   A                  A      True
# 6                   C                  C      True
# 7                   C                  C      True
# 8                   A                  A      True
# 9                   D                  D      True
# 10                  E                  E      True

# %% [markdown]
# Посчитаем количетсво значений "False" в этом столбце:

# %%
df['matching'].value_counts()
# Out:
# True     70832
# False    12323
# Name: matching, dtype: int64

# %% [markdown]
# Таких случаев было 12323.
# <br>
# <br>
# ## Узнать на какой месяц чаще всего оформляли бронь в 2016 году и изменился ли он в 2017 году?

# %% [markdown]
# Разобьем имеющиеся даты из столбца "arrival_full_date" на год, день, месяц. Запишем эти значения в отдельные столбцы, зададим им тип **int**

# %%
df["year"] = df["arrival_full_date"].apply(lambda x: x.split(".")[-1])
df["month"] = df["arrival_full_date"].apply(lambda x: x.split(".")[-2])
df["day"] = df["arrival_full_date"].apply(lambda x: x.split(".")[0])
df["year"] = df["year"].astype(int)
df["month"] = df["month"].astype(int)
df["day"] = df["day"].astype(int)

# %% [markdown]
# Примерим фильтр, указав, что год далжен быть 2015, а бронь не отменена.

# %%
df2 = df.query('year == 2015 and is_canceled == -1')
df2.head()
# Out:
#   hotel  is_canceled arrival_full_date  children  babies country  \
# 0     R           -1        01.07.2015         0       0     PRT
# 1     R           -1        01.07.2015         0       0     PRT
# 2     R           -1        01.07.2015         0       0     GBR
# 3     R           -1        01.07.2015         0       0     GBR
# 4     R           -1        01.07.2015         0       0     GBR
#
#   reserved_room_type assigned_room_type  matching  year  month  day
# 0                  C                  C      True  2015      7    1
# 1                  C                  C      True  2015      7    1
# 2                  A                  C     False  2015      7    1
# 3                  A                  A      True  2015      7    1
# 4                  A                  A      True  2015      7    1

# %% [markdown]
# Посчитаем сколько значений каждого месяца в колонке "month"

# %%
df2['month'].value_counts()
# Out:
# 9     2153
# 10    2090
# 8     1786
# 12    1498
# 11    1285
# 7     1119
# Name: month, dtype: int64

# %% [markdown]
# 9 месяц - больше всего успешных бронирований.
# <br>
# Теперь то же самое сделаем с фильтром на 2016 год.

# %%
df3 = df.query('year == 2016 and is_canceled == -1')
df3['month'].value_counts()
# Out:
# 8     2857
# 10    2781
# 3     2749
# 5     2646
# 7     2642
# 4     2585
# 9     2551
# 6     2459
# 11    2379
# 2     2098
# 12    2006
# 1     1407
# Name: month, dtype: int64

# %% [markdown]
# Видим, что 8 месяц является наиболее популярным по успешным бронированиям в 2016 году. Это отличается от 2017 года. Проверим теперь не только по бронированиям, которые не были отменены, а по всем броням:

# %%
df3 = df.query('year == 2015')
df3['month'].value_counts()
# Out:
# 9     2697
# 10    2521
# 8     2344
# 12    1856
# 7     1612
# 11    1525
# Name: month, dtype: int64

# %%
df3 = df.query('year == 2016')
df3['month'].value_counts()
# Out:
# 8     4279
# 10    3960
# 7     3709
# 3     3617
# 9     3613
# 4     3580
# 5     3569
# 6     3358
# 11    3180
# 12    2998
# 2     2610
# 1     1699
# Name: month, dtype: int64

# %% [markdown]
# Теперь ситуация поменялась, за 2015 год самый популярный месяц - 9, а в 2016 8. Таким образом месяц изменился.
#
# ## Понять на какой месяц (arrival_date_month) бронирования отеля типа City Hotel отменялись чаще всего в 2015? 2016? 2017?

# %% [markdown]
# Применим филльтр, в котором укажем, что тип отеля должен быть "City Hotel" и бронь должная быть отменеа:

# %%
df3 = df.query('hotel == "C" and is_canceled == 1')
df3.head()
# Out:
#       hotel  is_canceled arrival_full_date  children  babies country  \
# 40061     C            1        01.07.2015         0       0     PRT
# 40062     C            1        01.07.2015         0       0     PRT
# 40063     C            1        01.07.2015         0       0     PRT
# 40064     C            1        02.07.2015         0       0     PRT
# 40065     C            1        02.07.2015         0       0     PRT
#
#       reserved_room_type assigned_room_type  matching  year  month  day
# 40061                  A                  A      True  2015      7    1
# 40062                  A                  A      True  2015      7    1
# 40063                  A                  A      True  2015      7    1
# 40064                  A                  A      True  2015      7    2
# 40065                  A                  A      True  2015      7    2

# %% [markdown]
# Применим фильтр, в котром год должен быть 2015 и посчитаем в новой таблице значения каждого месяца.

# %%
df4 = df3.query('year == 2015')
df4["month"].value_counts()
# Out:
# 9     299
# 10    284
# 8     220
# 7     218
# 12    211
# 11    136
# Name: month, dtype: int64

# %% [markdown]
# Наибольшее значение - тот месяц, в котором бронирование отменялось чаще всего. По данным видно, что это 9 месяц (сентябрь).
# <br>
# Теперь сделаем аналогично с 2016 годом

# %%
df5 = df3.query('year == 2016')
df5["month"].value_counts()
# Out:
# 8     898
# 10    828
# 12    752
# 9     746
# 4     737
# 7     672
# 3     636
# 5     634
# 6     608
# 11    599
# 2     363
# 1     205
# Name: month, dtype: int64

# %% [markdown]
# Самый популярный месяц по отмене бронирования для этого типа отеля - 8 (август). И посчитаем то же самое для 2017 года:

# %%
df6 = df3.query('year == 2017')
df6["month"].value_counts()
# Out:
# 5    1088
# 4     988
# 7     977
# 8     960
# 6     902
# 3     715
# 2     599
# 1     543
# Name: month, dtype: int64

# %% [markdown]
# Больше всего отмен бронирования пришлось на 5 месяц (май).
# <br>
# ## Посчитать сколько клиентов было потеряно по двум группам: клиенты с детьми, клиенты без детей. Иными словами, посчитать метрику под названием Churn Rate.

# %% [markdown]
# Создадим отдельный столбик "kids", в котором укажем, есть ли дети или нет (значения True/False)

# %%
def count_children(x):
    ans = x["children"] + x["babies"]
    return ans != 0


df["kids"] = df.apply(count_children, axis=1)
df.head(15)
# Out:
#    hotel  is_canceled arrival_full_date  children  babies country  \
# 0      R           -1        01.07.2015         0       0     PRT
# 1      R           -1        01.07.2015         0       0     PRT
# 2      R           -1        01.07.2015         0       0     GBR
# 3      R           -1        01.07.2015         0       0     GBR
# 4      R           -1        01.07.2015         0       0     GBR
# 6      R           -1        01.07.2015         0       0     PRT
# 7      R           -1        01.07.2015         0       0     PRT
# 8      R            1        01.07.2015         0       0     PRT
# 9      R            1        01.07.2015         0       0     PRT
# 10     R            1        01.07.2015         0       0     PRT
# 11     R           -1        01.07.2015         0       0     PRT
# 12     R           -1        01.07.2015         0       0     USA
# 13     R           -1        01.07.2015         1       0     ESP
# 14     R           -1        01.07.2015         0       0     PRT
# 15     R           -1        01.07.2015         0       0     IRL
#
#    reserved_room_type assigned_room_type  matching  year  month  day   kids
# 0                   C                  C      True  2015      7    1  False
# 1                   C                  C      True  2015      7    1  False
# 2                   A                  C     False  2015      7    1  False
# 3                   A                  A      True  2015      7    1  False
# 4                   A                  A      True  2015      7    1  False
# 6                   C                  C      True  2015      7    1  False
# 7                   C                  C      True  2015      7    1  False
# 8                   A                  A      True  2015      7    1  False
# 9                   D                  D      True  2015      7    1  False
# 10                  E                  E      True  2015      7    1  False
# 11                  D                  D      True  2015      7    1  False
# 12                  D                  E     False  2015      7    1  False
# 13                  G                  G      True  2015      7    1   True
# 14                  E                  E      True  2015      7    1  False
# 15                  D                  E     False  2015      7    1  False

# %% [markdown]
# Теперь к новому столбику применим фильтр, в котором укажем, что детей нет. Посчитаем количество отмененных и успешных бронирований.

# %%
df7 = df.query("kids == False")
a = df7["is_canceled"].value_counts()
print(a)
# Out:
# -1    53598
#  1    20561
# Name: is_canceled, dtype: int64

# %% [markdown]
# Посчитаем какой процент от всех составлял отток:

# %%
a[1] / sum(a) * 100
# Out:
# 27.72556264243045

# %% [markdown]
# 27.7 процентов людей без детьми отменили бронирование. Посчитаем так же сколько людей с детьми отменили бронирование:

# %%
df8 = df.query("kids == True")
b = df8["is_canceled"].value_counts()
print(b)
# Out:
# -1    5902
#  1    3094
# Name: is_canceled, dtype: int64

# %%
b[1] / sum(b) * 100
# Out:
# 34.39306358381503

# %% [markdown]
# 34.4 процентов. Среди людей с детьми этот процент выше.
# <br>
# ## Вывод
# Итак, в процессе предобработки данных мне удалось избавиться от лишних столбцов, данные из которых не нужны были для решения поставленных задач. Также я проверила на наличие явных и неявных дубликатов. Помимо этого я  заменила пропущенные ячейки. Я создала несколько столбцов, данные в которых были продуктом анализа имеющихся столбцов.
# <br>
# <br>
# Я решила все имеющиеся задачи, что значит, что я провела анализ имеющихся данных, подробно описав каждый свой шаг.
